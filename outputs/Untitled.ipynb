# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

def preprocess_fit(train_df: pd.DataFrame, feature_cols, n_neighbors=5):
    X_train_raw = train_df[feature_cols].replace([np.inf, -np.inf], np.nan)

    imputer = KNNImputer(n_neighbors=n_neighbors, weights="distance")
    X_train_imp = imputer.fit_transform(X_train_raw)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train_imp)

    return X_train, imputer, scaler

def preprocess_apply(score_df: pd.DataFrame, feature_cols, imputer, scaler):
    X_score_raw = score_df[feature_cols].replace([np.inf, -np.inf], np.nan)
    X_score_imp = imputer.transform(X_score_raw)
    X_score = scaler.transform(X_score_imp)
    return X_score

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 5
#       1 from joblib import load
#       2 from pathlib import Path
# ----> 5 bundle = load("/Users/jenna/re-laiss/models/dimmad_medmed_bundle.joblib")
#       8 feature_cols = bundle["feature_cols"]
#       9 imputer = bundle["imputer"]
#
# File /opt/anaconda3/envs/relaiss-dev/lib/python3.10/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
# ...

# %%
print("Current directory:", os.getcwd())
print("Files here:", os.listdir())
print("Models folder exists:", os.path.exists("models"))
# Out:
# Current directory: /Users/jennakempster-taylor/re-laiss
# Files here: ['lightcurves', 'ztfdata.txt', '.DS_Store', 'reference_20k.csv', 'LICENSE', 'Untitled.ipynb', 'iforest_artifacts.joblib', 'experiments', 'dimmad_anomaly_rankings.csv', 'pyproject.toml', 'dimmad_medmed_bundle.joblib', 'tests', 'alerce_200_recent_iforest.csv', 'models', 'README.md', 'reference_matched_with_alerce.csv', 'DimmadTest.ipynb', '.gitignore', 'static', 'IsoForestDur.ipynb', 'examples', 'reference_unmatched_for_dimmad.csv', '.github', 'reference_20kk.csv', 'irsa_cutouts', '.ipynb_checkpoints', 'DimmadTest_cleaned.ipynb', '.git', 'data', 'outputs', 'notebooks', '.zenodo.json', 'robust_anomaly_cutouts', 'DIMMAD_scores_medmed_minmed.csv', 'src']
# Models folder exists: True

# %%
import os
os.chdir("/Users/jennakempster-taylor/re-laiss")

# %%
from joblib import load
from pathlib import Path


bundle = load("dimmad_medmed_bundle.joblib")


feature_cols = bundle["feature_cols"]
imputer = bundle["imputer"]
scaler = bundle["scaler"]
dimmad_medmed = bundle["dimmad_medmed"]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.feature.columns
#
# NameError: name 'df' is not defined

# %%
pip install alerce
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from alerce.core import Alerce
client = Alerce()

# %%
from astropy.time import Time
import pandas as pd



N_days = 2
mjd_min = Time.now().mjd - N_days

objs = client.query_objects(
    survey="lsst",
    lastmjd=mjd_min,
    page_size=200,
    format="pandas",
)

# sort locally (newest first)
objs = objs.sort_values("lastmjd", ascending=False)

objs.head()
# Out:
#               oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 110  ZTF21aadrzcd       33      2173  59226.564826  61097.564757       True
# 152  ZTF18acmbhmn        7      2524  58316.488947  61097.563102       True
# 130  ZTF18abfegfa        6      2549  58306.415868  61097.563102       True
# 82   ZTF19absnfkl        6      2855  58721.309780  61097.563102       True
# 98   ZTF19abwyqve       10      1741  58731.147060  61097.562616       True
#
#      stellar  ndet  g_r_max  g_r_max_corr  ...       lastmjd      deltajd  \
# 110    False    16      NaN           NaN  ...  61097.564757  1390.124525
# 152     True     3      NaN           NaN  ...  61097.563102  2661.478461
# 130     True     2      NaN           NaN  ...  61097.563102  2791.147234
# 82      True     3      NaN           NaN  ...  61097.563102  2376.253322
# 98      True     3      NaN           NaN  ...  61097.562616  2366.415555
#
# ...

# %% [markdown]
# ### Apply cuts as before (no need to look at VS etc)
